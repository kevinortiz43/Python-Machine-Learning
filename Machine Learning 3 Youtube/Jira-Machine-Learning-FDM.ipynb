# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Jira_1.csv")
# df["Issue_Type"] = (df["Issue_Type"] == "Bug").astype(int)
# df=df.drop(["Project key", "Project name","Project description", "Project url", "Resolution","Assignee Id", "Creatd", "Updated", "Last Viewed","Due date","Votes","Description","Environment"])
df.head()
# Out:
#                                              Summary Issue_key  Issue_id  \
# 0                     Decode base64 to display video  TMS-3291     55234
# 1                 Decode base64 to display PDF files  TMS-3290     55233
# 2  When user click on Download button of Download...  TMS-3289     55226
# 3  When user click on Cancel button of Download p...  TMS-3288     55225
# 4  When user click on Download button of Download...  TMS-3287     55224
#
#   Issue_Type Priority Resolution            Assignee  \
# 0   Sub-task   Medium        NaN     Alex Di Filippo
# 1   Sub-task   Medium        NaN  Geoffrey Nguyen-Do
# 2   Sub-task   Medium       Done    Hitesh Ghevariya
# 3   Sub-task   Medium       Done    Hitesh Ghevariya
# 4   Sub-task   Medium       Done    Hitesh Ghevariya
#
#                                    Assignee_Id            Reporter  \
# 0                     6410e284f1b529dfa98bcc29  Geoffrey Nguyen-Do
# 1  712020:65aad5ad-452d-4e43-a887-550e771381fd  Geoffrey Nguyen-Do
# ...
